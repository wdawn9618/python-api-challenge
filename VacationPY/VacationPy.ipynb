# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
import time

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
city = pd.read_csv("output_data.csv")
city.head()
# Out:
#    Unnamed: 0       City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0           0      Sémbé    1.6481    14.5806     79.30        70          93
# 1           1  Cape Town  -33.9258    18.4232     61.29        46          33
# 2           2    Ushuaia  -54.8000   -68.3000     36.70        85          60
# 3           3     Castro  -24.7911   -50.0119     70.07        41           1
# 4           4  Contamana   -7.3333   -75.0167     94.77        44          97
#
#    Wind Speed Country        Date
# 0        2.55      CG  1627236000
# 1        6.49      ZA  1627236000
# 2        5.59      AR  1627236000
# 3        7.70      BR  1627236000
# 4        1.90      PE  1627236000

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
locations = city[["Latitude", "Longitude"]]
Humidity = city["Humidity"]

# %%
figure = gmaps.figure(center=(46.0, -5.0), zoom_level=2)
maximum_intensity = np.max(Humidity)

# layer
heat_layer = gmaps.heatmap_layer(locations, weights = Humidity, dissipating=False, max_intensity=100, point_radius=3)

# Add layer
figure.add_layer(heat_layer)

# Display 
figure
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
ideal_city_df = city.loc[(city["Wind Speed"] <= 25) & (city["Cloudiness"] <= 10) & \
                                   (city["Max Temp"] >= 70) & (city["Max Temp"] <= 86)].dropna()

ideal_city_df
# Out:
#      Unnamed: 0                   City  Latitude  Longitude  Max Temp  \
# 3             3                 Castro  -24.7911   -50.0119     70.07
# 7             7     Puerto del Rosario   28.5004   -13.8627     77.29
# 39           39                Calnali   20.9167   -98.5833     75.76
# 45           45              Lielvārde   56.7207    24.8074     75.00
# 50           50                Kahului   20.8947  -156.4700     78.91
# 53           53              Hong Kong   22.2855   114.1577     85.24
# 63           63               Bengkulu   -3.8004   102.2655     76.96
# 66           66            Chake Chake   -5.2459    39.7666     74.89
# 79           79               Katsuura   35.1333   140.3000     76.84
# 87           87                Merrill   45.1805   -89.6835     80.67
# 92           92               Cidreira  -30.1811   -50.2056     74.28
# 106         106                 Hasaki   35.7333   140.8333     76.51
# 111         111             Kiryat Gat   31.6100    34.7642     83.97
# 114         114               Goderich   43.7501   -81.7165     73.60
# 122         122              Shelburne   44.0787   -80.2041     78.94
# 128         128                 Yining   29.0361   114.5636     76.82
# 129         129                  Alofi  -19.0595  -169.9187     77.43
# 152         152                  Aloha   45.4943  -122.8671     78.51
# 186         186            Derzhavīnsk   51.1000    66.3167     72.95
# 191         191                 Tiarei  -17.5333  -149.3333     76.55
# 208         208                 Pinawa   50.1489   -95.8811     80.82
# 232         232                 Faanui  -16.4833  -151.7500     77.77
# 247         247             Mossamedes  -15.1961    12.1522     72.66
# 285         285               Portland   45.5234  -122.6762     77.94
# 291         291           Ponta do Sol   32.6667   -17.1000     78.46
# 302         302           Quatre Cocos  -20.2078    57.7625     70.84
# 315         315            Gondanglegi   -7.7479   112.0132     71.56
# 333         333               Benguela  -12.5763    13.4055     73.65
# 362         362                Cilegon   -6.0174   106.0538     77.70
# 373         373                Manggar   -2.8833   108.2667     81.84
# 380         380            Zaozyornoye   45.1582    33.2787     80.83
# 384         384             Nouakchott   18.0858   -15.9785     83.35
# 426         426            Shubarkuduk   49.1447    56.4872     80.42
# 455         455                Aiquile  -18.2041   -65.1807     79.45
# 457         457          Cockburn Town   21.4612   -71.1419     82.65
# 458         458                Ludvika   60.1496    15.1878     79.43
# 462         462  Conceição das Alagoas  -19.9147   -48.3883     85.84
# 468         468                  Erice   38.0370    12.5865     82.13
# 499         499            Al Bardīyah   31.7561    25.0865     79.92
# 500         500                   Safi   32.2994    -9.2372     74.46
# 503         503                 Zaysan   47.4667    84.8667     74.89
# 511         511                Fayaoué  -20.6500   166.5333     73.58
# 528         528              Probistip   42.0031    22.1786     85.23
# 545         545               Boralday   43.3578    76.8594     82.24
# 548         548                Pitimbu   -7.4706   -34.8086     81.91
# 550         550                 Jishou   28.3167   109.7167     75.15
#
#      Humidity  Cloudiness  Wind Speed Country        Date
# 3          41           1        7.70      BR  1627236000
# 7          66           0       16.64      ES  1627236000
# 39         61           4        6.53      MX  1627236000
# 45         42           1        3.11      LV  1627236000
# 50         87           9       12.30      US  1627236000
# 53         83          10       10.20      HK  1627236000
# 63         89           3        4.83      ID  1627236000
# 66         64           1       16.91      TZ  1627236000
# 79         86           5       11.43      JP  1627236000
# 87         51           1       10.33      US  1627236000
# 92         53          10        6.53      BR  1627236000
# 106        79           0       14.23      JP  1627236000
# 111        63           0       11.56      IL  1627236000
# 114        77           0       10.51      CA  1627236000
# 122        56           7       13.06      CA  1627236000
# 128        87           5        1.61      CN  1627236000
# 129        88          10        4.79      NU  1627236000
# 152        58           1        4.99      US  1627236000
# 186        42           1        7.40      KZ  1627236000
# 191        67           2        9.93      PF  1627236000
# 208        33           3       11.43      CA  1627236000
# 232        66           4       13.11      PF  1627236000
# 247        55           0        3.80      AO  1627236000
# 285        61           1        5.21      US  1627236000
# 291        74           4        5.08      PT  1627236000
# 302        64           2       14.34      MU  1627236000
# 315        86           7        7.45      ID  1627236000
# 333        71           4        3.49      AO  1627236000
# 362        73           1        4.18      ID  1627236000
# 373        72           0       14.09      ID  1627236000
# 380        47           0       11.05      UA  1627236000
# 384        73           8       17.63      MR  1627236000
# 426        31          10        9.26      KZ  1627236000
# 455        27           0        6.71      BO  1627236000
# 457        80           7       11.41      TC  1627236000
# 458        31           4        6.17      SE  1627236000
# 462        21           0        6.60      BR  1627236000
# 468        25           1       11.12      IT  1627236000
# 499        56           0       13.24      LY  1627236000
# 500        64           0       20.54      MA  1627236000
# 503        38           9        6.93      KZ  1627236000
# 511        78           9       10.27      NC  1627236000
# 528        21           1        7.34      MK  1627236000
# 545        29           0        5.28      KZ  1627236000
# 548        68           5       13.87      BR  1627236000
# 550        91           1        1.66      CN  1627236000

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# Create a hotel_df
hotel_df = ideal_city_df.loc[:,["City","Country", "Latitude", "Longitude"]]

# Add a "Hotel Name" column to the DataFrame.
hotel_df["Hotel Name"] = ""

# Display the result
hotel_df
# Out:
#                       City Country  Latitude  Longitude Hotel Name
# 3                   Castro      BR  -24.7911   -50.0119
# 7       Puerto del Rosario      ES   28.5004   -13.8627
# 39                 Calnali      MX   20.9167   -98.5833
# 45               Lielvārde      LV   56.7207    24.8074
# 50                 Kahului      US   20.8947  -156.4700
# 53               Hong Kong      HK   22.2855   114.1577
# 63                Bengkulu      ID   -3.8004   102.2655
# 66             Chake Chake      TZ   -5.2459    39.7666
# 79                Katsuura      JP   35.1333   140.3000
# 87                 Merrill      US   45.1805   -89.6835
# 92                Cidreira      BR  -30.1811   -50.2056
# 106                 Hasaki      JP   35.7333   140.8333
# 111             Kiryat Gat      IL   31.6100    34.7642
# 114               Goderich      CA   43.7501   -81.7165
# 122              Shelburne      CA   44.0787   -80.2041
# 128                 Yining      CN   29.0361   114.5636
# 129                  Alofi      NU  -19.0595  -169.9187
# 152                  Aloha      US   45.4943  -122.8671
# 186            Derzhavīnsk      KZ   51.1000    66.3167
# 191                 Tiarei      PF  -17.5333  -149.3333
# 208                 Pinawa      CA   50.1489   -95.8811
# 232                 Faanui      PF  -16.4833  -151.7500
# 247             Mossamedes      AO  -15.1961    12.1522
# 285               Portland      US   45.5234  -122.6762
# 291           Ponta do Sol      PT   32.6667   -17.1000
# 302           Quatre Cocos      MU  -20.2078    57.7625
# 315            Gondanglegi      ID   -7.7479   112.0132
# 333               Benguela      AO  -12.5763    13.4055
# 362                Cilegon      ID   -6.0174   106.0538
# 373                Manggar      ID   -2.8833   108.2667
# 380            Zaozyornoye      UA   45.1582    33.2787
# 384             Nouakchott      MR   18.0858   -15.9785
# 426            Shubarkuduk      KZ   49.1447    56.4872
# 455                Aiquile      BO  -18.2041   -65.1807
# 457          Cockburn Town      TC   21.4612   -71.1419
# 458                Ludvika      SE   60.1496    15.1878
# 462  Conceição das Alagoas      BR  -19.9147   -48.3883
# 468                  Erice      IT   38.0370    12.5865
# 499            Al Bardīyah      LY   31.7561    25.0865
# 500                   Safi      MA   32.2994    -9.2372
# 503                 Zaysan      KZ   47.4667    84.8667
# 511                Fayaoué      NC  -20.6500   166.5333
# 528              Probistip      MK   42.0031    22.1786
# 545               Boralday      KZ   43.3578    76.8594
# 548                Pitimbu      BR   -7.4706   -34.8086
# 550                 Jishou      CN   28.3167   109.7167

# %%
#base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

#params = {"type" : "hotel",
 #         "keyword" : "hotel",
 #         "radius" : 5000,
 #         "key" : g_key}

# %%
for index, row in hotel_df.iterrows():
    try:
        
        base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

        params = {
        "keyword": "lodging",
        "radius": 5000,
        "key": g_key,
        }


        lat = row['Latitude']
        lng = row['Longitude']

        params['location'] = f"{lat}, {lng}"

        hotel_data = requests.get(base_url, params=params)
        places_data = hotel_data.json()
        
        hotel_df.loc[index, "Hotel Name"] = places_data["results"][0]["name"]
        
    except IndexError:
        
        hotel_df.loc[index, "Hotel Name"] = "NaN"
        
hotel_df
# Out:
#                       City Country  Latitude  Longitude Hotel Name
# 3                   Castro      BR  -24.7911   -50.0119        NaN
# 7       Puerto del Rosario      ES   28.5004   -13.8627        NaN
# 39                 Calnali      MX   20.9167   -98.5833        NaN
# 45               Lielvārde      LV   56.7207    24.8074        NaN
# 50                 Kahului      US   20.8947  -156.4700        NaN
# 53               Hong Kong      HK   22.2855   114.1577        NaN
# 63                Bengkulu      ID   -3.8004   102.2655        NaN
# 66             Chake Chake      TZ   -5.2459    39.7666        NaN
# 79                Katsuura      JP   35.1333   140.3000        NaN
# 87                 Merrill      US   45.1805   -89.6835        NaN
# 92                Cidreira      BR  -30.1811   -50.2056        NaN
# 106                 Hasaki      JP   35.7333   140.8333        NaN
# 111             Kiryat Gat      IL   31.6100    34.7642        NaN
# 114               Goderich      CA   43.7501   -81.7165        NaN
# 122              Shelburne      CA   44.0787   -80.2041        NaN
# 128                 Yining      CN   29.0361   114.5636        NaN
# 129                  Alofi      NU  -19.0595  -169.9187        NaN
# 152                  Aloha      US   45.4943  -122.8671        NaN
# 186            Derzhavīnsk      KZ   51.1000    66.3167        NaN
# 191                 Tiarei      PF  -17.5333  -149.3333        NaN
# 208                 Pinawa      CA   50.1489   -95.8811        NaN
# 232                 Faanui      PF  -16.4833  -151.7500        NaN
# 247             Mossamedes      AO  -15.1961    12.1522        NaN
# 285               Portland      US   45.5234  -122.6762        NaN
# 291           Ponta do Sol      PT   32.6667   -17.1000        NaN
# 302           Quatre Cocos      MU  -20.2078    57.7625        NaN
# 315            Gondanglegi      ID   -7.7479   112.0132        NaN
# 333               Benguela      AO  -12.5763    13.4055        NaN
# 362                Cilegon      ID   -6.0174   106.0538        NaN
# 373                Manggar      ID   -2.8833   108.2667        NaN
# 380            Zaozyornoye      UA   45.1582    33.2787        NaN
# 384             Nouakchott      MR   18.0858   -15.9785        NaN
# 426            Shubarkuduk      KZ   49.1447    56.4872        NaN
# 455                Aiquile      BO  -18.2041   -65.1807        NaN
# 457          Cockburn Town      TC   21.4612   -71.1419        NaN
# 458                Ludvika      SE   60.1496    15.1878        NaN
# 462  Conceição das Alagoas      BR  -19.9147   -48.3883        NaN
# 468                  Erice      IT   38.0370    12.5865        NaN
# 499            Al Bardīyah      LY   31.7561    25.0865        NaN
# 500                   Safi      MA   32.2994    -9.2372        NaN
# 503                 Zaysan      KZ   47.4667    84.8667        NaN
# 511                Fayaoué      NC  -20.6500   166.5333        NaN
# 528              Probistip      MK   42.0031    22.1786        NaN
# 545               Boralday      KZ   43.3578    76.8594        NaN
# 548                Pitimbu      BR   -7.4706   -34.8086        NaN
# 550                 Jishou      CN   28.3167   109.7167        NaN

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info= [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Latitude", "Longitude"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations, info_box_content = hotel_info)

# Add the layer to the map
fig.add_layer(markers)
#Display map
fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-0ddc0af3c3aa> in <module>
#       3
#       4 # Add the layer to the map
# ----> 5 fig.add_layer(markers)
#       6 #Display map
#       7 fig
#
# NameError: name 'fig' is not defined
